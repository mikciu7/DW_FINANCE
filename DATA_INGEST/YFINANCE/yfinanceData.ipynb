# %%
import yfinance as yf
df = yf.download("AAPL", start="2010-01-01", end="2025-01-01")
# Out:
# /tmp/ipykernel_46908/2488967052.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", start="2010-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
ticker = yf.Ticker("AAPL")
info = ticker.info

# %%
import pandas as pd

useful = {
    "symbol": info.get("symbol"),
    "longName": info.get("longName"),
    "sector": info.get("sector"),
    "industry": info.get("industry"),
    "marketCap": info.get("marketCap"),
    "enterpriseValue": info.get("enterpriseValue"),
    "beta": info.get("beta"),
    "forwardPE": info.get("forwardPE"),
    "trailingPE": info.get("trailingPE"),
    "priceToBook": info.get("priceToBook"),
    "dividendYield": info.get("dividendYield"),
    "fiftyTwoWeekHigh": info.get("fiftyTwoWeekHigh"),
    "fiftyTwoWeekLow": info.get("fiftyTwoWeekLow"),
    "averageVolume": info.get("averageVolume"),
    "sharesOutstanding": info.get("sharesOutstanding"),
    "floatShares": info.get("floatShares"),
    "shortPercentOfFloat": info.get("shortPercentOfFloat"),
}
pd.Series(useful)
# Out:
# symbol                                 AAPL
# longName                         Apple Inc.
# sector                           Technology
# industry               Consumer Electronics
# marketCap                     3953560911872
# enterpriseValue               4052762492928
# beta                                  1.094
# forwardPE                          32.19735
# trailingPE                         35.86595
# priceToBook                       53.608494
# dividendYield                          0.38
# fiftyTwoWeekHigh                     277.32
# fiftyTwoWeekLow                      169.21
# averageVolume                      54316450
# sharesOutstanding               14773260000
# floatShares                     14750198855
# shortPercentOfFloat                  0.0074
# dtype: object

# %%
print(pd.Series(info).head(50))
# Out:
# address1                                                     One Apple Park Way
# city                                                                  Cupertino
# state                                                                        CA
# zip                                                                       95014
# country                                                           United States
# phone                                                            (408) 996-1010
# website                                                   https://www.apple.com
# industry                                                   Consumer Electronics
# industryKey                                                consumer-electronics
# industryDisp                                               Consumer Electronics
# sector                                                               Technology
# sectorKey                                                            technology
# sectorDisp                                                           Technology
# longBusinessSummary           Apple Inc. designs, manufactures, and markets ...
# fullTimeEmployees                                                        166000
# companyOfficers               [{'maxAge': 1, 'name': 'Mr. Timothy D. Cook', ...
# auditRisk                                                                     7
# boardRisk                                                                     1
# compensationRisk                                                              3
# shareHolderRightsRisk                                                         1
# overallRisk                                                                   1
# governanceEpochDate                                                  1761955200
# compensationAsOfEpochDate                                            1735603200
# irWebsite                                            http://investor.apple.com/
# executiveTeam                                                                []
# maxAge                                                                    86400
# priceHint                                                                     2
# previousClose                                                            270.37
# open                                                                     270.42
# dayLow                                                                   266.25
# dayHigh                                                                  270.85
# regularMarketPreviousClose                                               270.37
# regularMarketOpen                                                        270.42
# regularMarketDayLow                                                      266.25
# regularMarketDayHigh                                                     270.85
# dividendRate                                                               1.04
# dividendYield                                                              0.38
# exDividendDate                                                       1762732800
# payoutRatio                                                              0.1367
# fiveYearAvgDividendYield                                                   0.53
# beta                                                                      1.094
# trailingPE                                                             35.86595
# forwardPE                                                              32.19735
# volume                                                                 32024891
# regularMarketVolume                                                    32024481
# averageVolume                                                          54316450
# averageVolume10days                                                    54669570
# averageDailyVolume10Day                                                54669570
# bid                                                                      267.03
# ask                                                                      268.97
# dtype: object

# %%
ticker.institutional_holders
# Out:
#   Date Reported                         Holder  pctHeld      Shares  \
# 0    2025-06-30             Vanguard Group Inc   0.0954  1415932804
# 1    2025-06-30                 Blackrock Inc.   0.0774  1148838990
# 2    2025-06-30       State Street Corporation   0.0405   601249995
# 3    2025-06-30  Geode Capital Management, LLC   0.0239   354749794
# 4    2025-06-30                       FMR, LLC   0.0207   306758594
# 5    2025-06-30        Berkshire Hathaway, Inc   0.0189   280000000
# 6    2025-06-30                 Morgan Stanley   0.0157   233198646
# 7    2025-06-30            JPMORGAN CHASE & CO   0.0145   214606399
# 8    2025-06-30  Price (T.Rowe) Associates Inc   0.0137   202720404
# 9    2025-06-30                    NORGES BANK   0.0128   189804820
#
#           Value  pctChange
# 0  378946103248     0.0108
# 1  307463784503     0.0076
# 2  160912539097     0.0088
# 3   94941689100     0.0141
# 4   82097804010    -0.0650
# 5   74936401367    -0.0667
# 6   62410954767    -0.0333
# 7   57435111612     0.0798
# 8   54254062712    -0.0558
# 9   50797464903     0.0141

# %%
ticker.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          5   24    15     1           3
# 1    -1m          5   24    15     1           3
# 2    -2m          5   23    15     1           3
# 3    -3m          5   22    15     1           1

# %%
ticker.quarterly_earnings
# Out:
# /home/mikciu/PROJEKT/neoeye/lib/python3.11/site-packages/yfinance/scrapers/fundamentals.py:36: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)
