# %%
from QuarterlyBalanceSheet import QuarterlyBalanceSheet

# %%
qbs = QuarterlyBalanceSheet()

# %% [markdown]
# df = qbs.get_latest_quarterly_report("AAPL")

# %%
df
# Out:
#                                           label balance  2025-09-30  \
# 0                              Accounts Payable  credit     32580.0
# 1                           Accounts Receivable   debit     52894.0
# 2                           Accrued Liabilities    None      9201.0
# 3   Accumulated Other Comprehensive Income/Loss  credit     -2761.0
# 4                     Cash and Cash Equivalents   debit     28849.0
# 5                     Cash and Cash Equivalents    None    102012.0
# 6                                  Common Stock    None    110964.0
# 7                         Deferred income taxes    None      2852.0
# 8                                      Goodwill   debit    119497.0
# 9                             Intangible Assets    None     21236.0
# 10                                    Inventory   debit      1130.0
# 11                               Long Term Debt  credit     35376.0
# 12                        Long-Term Investments   debit     11465.0
# 13                       Long-term income taxes    None     26569.0
# 14                   Long-term unearned revenue    None      2546.0
# 15                  Operating lease liabilities    None     17348.0
# 16          Operating lease right-of-use assets    None     24791.0
# 17                         Other Current Assets   debit     33030.0
# 18                    Other Current Liabilities  credit     22741.0
# 19                     Other Non Current Assets   debit     39435.0
# 20                Other Non Current Liabilities  credit     53588.0
# 21                Property, Plant and Equipment   debit    230861.0
# 22                            Retained Earnings  credit    254873.0
# 23                              Short Term Debt  credit      7832.0
# 24                      Short-term income taxes  credit      3655.0
# 25                       Short-term investments   debit     73163.0
# 26                  Short-term unearned revenue  credit     58987.0
# 27                                 Total Assets   debit    636351.0
# 28                         Total Current Assets   debit    189066.0
# 29                    Total Current Liabilities  credit    134996.0
# 30                            Total Liabilities  credit    273275.0
# 31   Total Liabilities and Stockholders' Equity  credit    636351.0
# 32                   Total Stockholders' Equity  credit    363076.0
#
#     2025-06-30                    bs_category
# 0      27724.0               accounts_payable
# 1      69905.0            accounts_receivable
# 2      13709.0                           None
# 3      -3347.0                           None
# 4      30242.0      cash_and_cash_equivalents
# 5      94565.0                           None
# 6     109095.0                   common_stock
# 7       2835.0                           None
# 8     119509.0                       goodwill
# 9      22604.0                           None
# 10       938.0                      inventory
# 11     40152.0                 long_term_debt
# 12     15405.0                           None
# 13     25986.0                           None
# 14      2710.0               deferred_revenue
# 15     17437.0                           None
# 16     24823.0                           None
# 17     25723.0           other_current_assets
# 18     25020.0      other_current_liabilities
# 19     40565.0       total_non_current_assets
# 20     45186.0  other_non_current_liabilities
# 21    204966.0                            ppe
# 22    237731.0              retained_earnings
# 23      2999.0                short_term_debt
# 24      7211.0                           None
# 25     64323.0                           None
# 26     64555.0               deferred_revenue
# 27    619003.0                   total_assets
# 28    191131.0           total_current_assets
# 29    141218.0      total_current_liabilities
# 30    275524.0              total_liabilities
# 31    619003.0         liabilities_and_equity
# 32    343479.0            stockholders_equity

# %%
from edgar import Company, set_identity

set_identity("Mikolaj Ciuba ciubamikolaj22@gmail.com")

company = Company("MSFT")
    
filing = company.get_filings(form="10-Q").latest()

xbrl = filing.xbrl()
xbrl.statements.balance_sheet()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             Consolidated Balance Sheets
#                     As of September 30, 2025 and June 30, 2025
#                   (In millions, except shares and per share data)
#
#                                                       Sep 30, 2025   Jun 30, 2025
#  ─────────────────────────────────────────────────────────────────────────────────
#   Assets
#     Current assets:
#         Cash and Cash Equivalents                          $28,849        $30,242
#         Short-term investments                             $73,163        $64,323
#         Cash and Cash Equivalents                         $102,012        $94,565
#         Accounts Receivable                                $52,894        $69,905
#         Inventory                                           $1,130           $938
#         Other Current Assets                               $33,030        $25,723
#         Total Current Assets                              $189,066       $191,131
#       Property, Plant and Equipment                       $230,861       $204,966
#       Operating lease right-of-use assets                  $24,791        $24,823
#       Long-Term Investments                                $11,465        $15,405
#       Goodwill                                            $119,497       $119,509
#       Intangible Assets                                    $21,236        $22,604
#       Other Non Current Assets                             $39,435        $40,565
#       Total Assets                                        $636,351       $619,003
#   Liabilities and stockholders’ equity
#     Current liabilities:
#         Accounts Payable                                   $32,580        $27,724
#         Short Term Debt                                     $7,832         $2,999
#         Accrued Liabilities                                 $9,201        $13,709
#         Short-term income taxes                             $3,655         $7,211
#         Short-term unearned revenue                        $58,987        $64,555
#         Other Current Liabilities                          $22,741        $25,020
#         Total Current Liabilities                         $134,996       $141,218
#       Long Term Debt                                       $35,376        $40,152
#       Long-term income taxes                               $26,569        $25,986
#       Long-term unearned revenue                            $2,546         $2,710
#       Deferred income taxes                                 $2,852         $2,835
#       Operating lease liabilities                          $17,348        $17,437
#       Other Non Current Liabilities                        $53,588        $45,186
#       Total Liabilities                                   $273,275       $275,524
#       Commitments and contingencies
#     Stockholders’ equity:
#         Common Stock                                      $110,964       $109,095
#         Retained Earnings                                 $254,873       $237,731
#         Accumulated Other Comprehensive Income/Loss       $(2,761)       $(3,347)
#         Total Stockholders' Equity                        $363,076       $343,479
#       Total Liabilities and Stockholders' Equity          $636,351       $619,003
#
#   MICROSOFT CORPORATION • Period ending 2025-09-30 • Fiscal Q1 • Source: SEC XBRL

# %%
stmt = qbs.xbrl.statements.balance_sheet()
df = stmt.to_dataframe()

# %%
df
# Out:
#                                               concept  \
# 0                      us-gaap_AccountsPayableCurrent
# 1                us-gaap_AccountsReceivableNetCurrent
# 2   us-gaap_AccumulatedOtherComprehensiveIncomeLos...
# 3       us-gaap_CashAndCashEquivalentsAtCarryingValue
# 4                             us-gaap_CommercialPaper
# 5   us-gaap_CommonStocksIncludingAdditionalPaidInC...
# 6                 us-gaap_MarketableSecuritiesCurrent
# 7        us-gaap_ContractWithCustomerLiabilityCurrent
# 8                                us-gaap_InventoryNet
# 9                      us-gaap_LongTermDebtNoncurrent
# 10             us-gaap_MarketableSecuritiesNoncurrent
# 11                         us-gaap_OtherAssetsCurrent
# 12                    us-gaap_OtherLiabilitiesCurrent
# 13                      us-gaap_OtherAssetsNoncurrent
# 14                 us-gaap_OtherLiabilitiesNoncurrent
# 15               us-gaap_PropertyPlantAndEquipmentNet
# 16         us-gaap_RetainedEarningsAccumulatedDeficit
# 17                        us-gaap_LongTermDebtCurrent
# 18                                     us-gaap_Assets
# 19                              us-gaap_AssetsCurrent
# 20                         us-gaap_LiabilitiesCurrent
# 21                                us-gaap_Liabilities
# 22           us-gaap_LiabilitiesAndStockholdersEquity
# 23                           us-gaap_AssetsNoncurrent
# 24                      us-gaap_LiabilitiesNoncurrent
# 25                         us-gaap_StockholdersEquity
# 26                 us-gaap_NontradeReceivablesCurrent
#
#                                           label  dimension balance  \
# 0                              Accounts Payable      False  credit
# 1                           Accounts Receivable      False   debit
# 2   Accumulated Other Comprehensive Income/Loss      False  credit
# 3                     Cash and Cash Equivalents      False   debit
# 4                              Commercial paper      False  credit
# 5                                  Common Stock      False    None
# 6                 Current Marketable Securities      False    None
# 7                              Deferred revenue      False  credit
# 8                                     Inventory      False   debit
# 9                                Long Term Debt      False  credit
# 10            Non Current Marketable Securities      False    None
# 11                         Other Current Assets      False   debit
# 12                    Other Current Liabilities      False  credit
# 13                     Other Non Current Assets      False   debit
# 14                Other Non Current Liabilities      False  credit
# 15                Property, Plant and Equipment      False   debit
# 16                            Retained Earnings      False  credit
# 17                              Short Term Debt      False  credit
# 18                                 Total Assets      False   debit
# 19                         Total Current Assets      False   debit
# 20                    Total Current Liabilities      False  credit
# 21                            Total Liabilities      False  credit
# 22   Total Liabilities and Stockholders' Equity      False  credit
# 23                     Total Non Current Assets      False   debit
# 24                Total Non Current Liabilities      False  credit
# 25                   Total Stockholders' Equity      False  credit
# 26                 Vendor non-trade receivables      False    None
#
#     2025-06-28  2024-09-28
# 0      50374.0     68960.0
# 1      27557.0     33410.0
# 2      -6369.0     -7172.0
# 3      36269.0     29943.0
# 4       9923.0      9967.0
# 5      89806.0     83276.0
# 6      19103.0     35228.0
# 7       8979.0      8249.0
# 8       5925.0      7286.0
# 9      82430.0     85750.0
# 10     77614.0     91479.0
# 11     14359.0     14287.0
# 12     62499.0     78304.0
# 13     82882.0     74834.0
# 14     42115.0     45888.0
# 15     48508.0     45680.0
# 16    -17607.0    -19154.0
# 17      9345.0     10912.0
# 18    331495.0    364980.0
# 19    122491.0    152987.0
# 20    141120.0    176392.0
# 21    265665.0    308030.0
# 22    331495.0    364980.0
# 23    209004.0    211993.0
# 24    124545.0    131638.0
# 25     65830.0     56950.0
# 26     19278.0     32833.0

# %%
import re
import pandas as pd

def tidy_statement_numeric(df):
        
        df = df.copy()
    
        date_cols = [c for c in df.columns if re.match(r"\d{4}-\d{2}-\d{2}", str(c))]
    
        has_value = df[date_cols].apply(pd.to_numeric, errors="coerce").notna().any(axis=1)
        out = df.loc[has_value].copy()
    
        if "preferred_sign" in out.columns:
            for c in date_cols:
                out[c] = pd.to_numeric(out[c], errors="coerce")
            neg = out["preferred_sign"] == -1
            out.loc[neg, date_cols] = -out.loc[neg, date_cols]
    
        keep_cols = ["concept", "label"]
        if "dimension" in out.columns:
            keep_cols.append("dimension")
        if "balance" in out.columns:
            keep_cols.append("balance")
    
        tidy = out[keep_cols + date_cols].sort_values("label").reset_index(drop=True)
        return tidy

# %%
tidy = tidy_statement_numeric(df)

# %%
tidy
# Out:
#                                               concept  \
# 0                      us-gaap_AccountsPayableCurrent
# 1                us-gaap_AccountsReceivableNetCurrent
# 2           us-gaap_EmployeeRelatedLiabilitiesCurrent
# 3   us-gaap_AccumulatedOtherComprehensiveIncomeLos...
# 4       us-gaap_CashAndCashEquivalentsAtCarryingValue
# 5   us-gaap_CashCashEquivalentsAndShortTermInvestm...
# 6   us-gaap_CommonStocksIncludingAdditionalPaidInC...
# 7             us-gaap_DeferredIncomeTaxLiabilitiesNet
# 8                                    us-gaap_Goodwill
# 9              us-gaap_FiniteLivedIntangibleAssetsNet
# 10                               us-gaap_InventoryNet
# 11                     us-gaap_LongTermDebtNoncurrent
# 12                        us-gaap_LongTermInvestments
# 13               us-gaap_AccruedIncomeTaxesNoncurrent
# 14    us-gaap_ContractWithCustomerLiabilityNoncurrent
# 15          us-gaap_OperatingLeaseLiabilityNoncurrent
# 16              us-gaap_OperatingLeaseRightOfUseAsset
# 17                         us-gaap_OtherAssetsCurrent
# 18                    us-gaap_OtherLiabilitiesCurrent
# 19                      us-gaap_OtherAssetsNoncurrent
# 20                 us-gaap_OtherLiabilitiesNoncurrent
# 21               us-gaap_PropertyPlantAndEquipmentNet
# 22         us-gaap_RetainedEarningsAccumulatedDeficit
# 23                        us-gaap_LongTermDebtCurrent
# 24                  us-gaap_AccruedIncomeTaxesCurrent
# 25                       us-gaap_ShortTermInvestments
# 26       us-gaap_ContractWithCustomerLiabilityCurrent
# 27                                     us-gaap_Assets
# 28                              us-gaap_AssetsCurrent
# 29                         us-gaap_LiabilitiesCurrent
# 30                                us-gaap_Liabilities
# 31           us-gaap_LiabilitiesAndStockholdersEquity
# 32                         us-gaap_StockholdersEquity
#
#                                           label  dimension balance  \
# 0                              Accounts Payable      False  credit
# 1                           Accounts Receivable      False   debit
# 2                           Accrued Liabilities      False    None
# 3   Accumulated Other Comprehensive Income/Loss      False  credit
# 4                     Cash and Cash Equivalents      False   debit
# 5                     Cash and Cash Equivalents      False    None
# 6                                  Common Stock      False    None
# 7                         Deferred income taxes      False    None
# 8                                      Goodwill      False   debit
# 9                             Intangible Assets      False    None
# 10                                    Inventory      False   debit
# 11                               Long Term Debt      False  credit
# 12                        Long-Term Investments      False   debit
# 13                       Long-term income taxes      False    None
# 14                   Long-term unearned revenue      False    None
# 15                  Operating lease liabilities      False    None
# 16          Operating lease right-of-use assets      False    None
# 17                         Other Current Assets      False   debit
# 18                    Other Current Liabilities      False  credit
# 19                     Other Non Current Assets      False   debit
# 20                Other Non Current Liabilities      False  credit
# 21                Property, Plant and Equipment      False   debit
# 22                            Retained Earnings      False  credit
# 23                              Short Term Debt      False  credit
# 24                      Short-term income taxes      False  credit
# 25                       Short-term investments      False   debit
# 26                  Short-term unearned revenue      False  credit
# 27                                 Total Assets      False   debit
# 28                         Total Current Assets      False   debit
# 29                    Total Current Liabilities      False  credit
# 30                            Total Liabilities      False  credit
# 31   Total Liabilities and Stockholders' Equity      False  credit
# 32                   Total Stockholders' Equity      False  credit
#
#       2025-09-30    2025-06-30
# 0   3.258000e+10  2.772400e+10
# 1   5.289400e+10  6.990500e+10
# 2   9.201000e+09  1.370900e+10
# 3  -2.761000e+09 -3.347000e+09
# 4   2.884900e+10  3.024200e+10
# 5   1.020120e+11  9.456500e+10
# 6   1.109640e+11  1.090950e+11
# 7   2.852000e+09  2.835000e+09
# 8   1.194970e+11  1.195090e+11
# 9   2.123600e+10  2.260400e+10
# 10  1.130000e+09  9.380000e+08
# 11  3.537600e+10  4.015200e+10
# 12  1.146500e+10  1.540500e+10
# 13  2.656900e+10  2.598600e+10
# 14  2.546000e+09  2.710000e+09
# 15  1.734800e+10  1.743700e+10
# 16  2.479100e+10  2.482300e+10
# 17  3.303000e+10  2.572300e+10
# 18  2.274100e+10  2.502000e+10
# 19  3.943500e+10  4.056500e+10
# 20  5.358800e+10  4.518600e+10
# 21  2.308610e+11  2.049660e+11
# 22  2.548730e+11  2.377310e+11
# 23  7.832000e+09  2.999000e+09
# 24  3.655000e+09  7.211000e+09
# 25  7.316300e+10  6.432300e+10
# 26  5.898700e+10  6.455500e+10
# 27  6.363510e+11  6.190030e+11
# 28  1.890660e+11  1.911310e+11
# 29  1.349960e+11  1.412180e+11
# 30  2.732750e+11  2.755240e+11
# 31  6.363510e+11  6.190030e+11
# 32  3.630760e+11  3.434790e+11
