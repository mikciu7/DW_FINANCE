# %%
from StatementsFetcher import StatementsFetcher

# %%
sf = StatementsFetcher()

# %%
# [income_df, balance_df, cashflow_df] = sf.fetch_statements(2005, 1, 2005, 1, "AAPL")
sf.fetch_statements(1994, 7, 1994, 8, "AAPL")
# Out:
# Pobieram 1994Q3...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [╭─────────────────── Form 10-Q Apple Inc. [320193]  ────────────────────╮
# │                                                                       │
# │   Accession Number       Filing Date   Period of Report   Documents   │
# │  ───────────────────────────────────────────────────────────────────  │
# │   0000320193-94-000013   1994-08-12    1994-07-01         2           │
# │                                                                       │
# ╰─ Quarterly report for public companies • filing.docs for usage guide ─╯
# ]
# TEXT
# [                                                Label        1994        1993
# 0   Net sales                  $2,149,908 $ 1,861,979  6695462.00  5836165.00
# 1   Cost of sales               1,576,036   1,255,975  5030502.00  3658473.00
# ...

# %%
income_df
# Out:
#                                                 Label  \
# 0                                       Cost of sales
# 1                                                 NaN
# 2                                 Operating expenses:
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
balance_df
# Out:
#                                                 Label March 26, 2005  \
# 0                          Cash and  cash equivalents           <NA>
# 1                             Short-term  investments           4803
# 2   Accounts  receivable, less allowances of $51 a...            888
# 3                                         Inventories            164
# 4                                Deferred tax  assets            297
# 5                               Other  current assets            601
# 6                               Total  current assets           9007
# 7                 Property,  plant and equipment, net            742
# 8                                            Goodwill             80
# 9                         Acquired  intangible assets             33
# 10                                       Other assets            249
# 11                                       Total assets           <NA>
# 12                                  Accounts  payable           <NA>
# ...

# %%
cashflow_df
# Out:
#                                                 Label Six Months Ended  \
# 0                                                 NaN   March 26, 2005
# 1   Cash and  cash equivalents, beginning of the p...             <NA>
# 2                                          Net income              585
# 3          Depreciation,  amortization, and accretion               82
# 4                   Stock based  compensation expense               20
# 5   Provision  for (benefit from) deferred income ...               13
# 6                     Tax benefit  from stock options              275
# 7   Loss on  disposition of property, plant, and e...                4
# 8                   Gains on  non-current investments             <NA>
# 9                           Accounts  receivable, net             (114
# 10                                        Inventories              (63
# 11                              Other  current assets             (116
# ...
