# %%
from QuarterlyCashFlow import QuarterlyCashFlow

# %%
qcf = QuarterlyCashFlow()

# %%
qcf.get_latest_quarterly_report("MSFT")
# Out:
#                                                 label balance  2025-09-30  \
# 0                                    Accounts payable    None      -614.0
# 1                                 Accounts receivable    None     16490.0
# 2   Acquisition of companies, net of cash acquired...  credit      -578.0
# 3                    Common stock cash dividends paid  credit     -6169.0
# 4                            Common stock repurchased  credit     -5650.0
# 5                               Deferred income taxes   debit      2491.0
# 6               Depreciation, amortization, and other   debit     13061.0
# 7   Effect of foreign exchange rates on cash and c...    None       -92.0
# 8                                        Income taxes    None     -2944.0
# 9                                         Inventories    None      -192.0
# 10                 Net Cash from Financing Activities   debit    -11799.0
# 11                 Net Cash from Investing Activities   debit    -34559.0
# 12                 Net Cash from Operating Activities   debit     45057.0
# 13                                 Net Change in Cash    None     -1393.0
# 14                                         Net Income  credit     27747.0
# 15  Net recognized gains on investments and deriva...  credit     -1007.0
# 16                               Other current assets    None     -1162.0
# 17                          Other current liabilities    None     -5507.0
# 18                             Other long-term assets    None      -394.0
# 19                        Other long-term liabilities    None      -477.0
# 20                                         Other, net    None      -669.0
# 21                                         Other, net    None     -6209.0
# 22         Payments for Property, Plant and Equipment  credit    -19394.0
# 23             Proceeds from Issuance of Common Stock   debit       689.0
# 24  Proceeds from Maturities, Prepayments and Call...    None      6031.0
# 25                           Purchases of investments    None    -17671.0
# 26                                 Repayments of debt    None        -0.0
# 27  Repayments of debt, maturities of 90 days or less    None         0.0
# 28                               Sales of investments   debit      3262.0
# 29                   Stock-based compensation expense   debit      2983.0
# 30                                   Unearned revenue    None     -5418.0
#
#     2024-09-30                               cf_category
# 0       -916.0                change_in_accounts_payable
# 1      14037.0             change_in_accounts_receivable
# 2      -1849.0              acquisitions_and_intangibles
# 3      -5574.0                            dividends_paid
# 4      -4107.0                         share_repurchases
# 5      -1433.0                     deferred_income_taxes
# 6       7383.0       depreciation_amortization_and_other
# 7        122.0           effect_of_exchange_rate_on_cash
# 8       1016.0            change_in_income_taxes_payable
# 9       -373.0                     change_in_inventories
# 10    -16576.0        net_cash_from_financing_activities
# 11    -15201.0        net_cash_from_investing_activities
# 12     34180.0        net_cash_from_operating_activities
# 13      2525.0                        net_change_in_cash
# 14     24667.0                                net_income
# 15      -125.0  gain_loss_on_investments_and_derivatives
# 16       -82.0            change_in_other_current_assets
# 17     -5479.0       change_in_other_current_liabilities
# 18     -1761.0            change_in_other_current_assets
# 19       -33.0       change_in_other_current_liabilities
# 20      -889.0                other_financing_cash_flows
# 21      -913.0                other_investing_cash_flows
# 22    -14923.0                      capital_expenditures
# 23       706.0       proceeds_from_common_stock_issuance
# 24      2136.0                  maturities_of_securities
# 25     -1620.0                  purchases_of_investments
# 26      -966.0              repayments_of_long_term_debt
# 27     -5746.0                  short_term_debt_activity
# 28      1968.0                 proceeds_from_investments
# 29      2832.0                  share_based_compensation
# 30     -5553.0              change_in_contract_liability

# %%
from edgar import Company, set_identity

set_identity("Mikolaj Ciuba ciubamikolaj22@gmail.com")

company = Company("MSFT")
    
filing = company.get_filings(form="10-Q").latest()

xbrl = filing.xbrl()
xbrl.statements.cashflow_statement()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                        Consolidated Statement of Cash Flows
#                                                 Three Months Ended
#                                   (In millions, except shares and per share data)
#
#                                                                             Sep 30, 2025 (Q3)   Sep 30, 2024 (Q3)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Operations
#       Net Income                                                                      $27,747             $24,667
#     Adjustments to reconcile net income to net cash from operations:
#         Depreciation, amortization, and other                                         $13,061              $7,383
#         Stock-based compensation expense                                               $2,983              $2,832
#         Net recognized gains on investments and derivatives                          $(1,007)              $(125)
#         Deferred income taxes                                                          $2,491            $(1,433)
#     Changes in operating assets and liabilities:
#         Accounts receivable                                                           $16,490             $14,037
#         Inventories                                                                    $(192)              $(373)
#         Other current assets                                                         $(1,162)               $(82)
#         Other long-term assets                                                         $(394)            $(1,761)
#         Accounts payable                                                               $(614)              $(916)
#         Unearned revenue                                                             $(5,418)            $(5,553)
#         Income taxes                                                                 $(2,944)              $1,016
#         Other current liabilities                                                    $(5,507)            $(5,479)
#         Other long-term liabilities                                                    $(477)               $(33)
#       Net Cash from Operating Activities                                              $45,057             $34,180
#   Financing
#       Repayments of debt, maturities of 90 days or less                                                  $(5,746)
#       Repayments of debt                                                                                   $(966)
#       Proceeds from Issuance of Common Stock                                             $689                $706
#       Common stock repurchased                                                       $(5,650)            $(4,107)
#       Common stock cash dividends paid                                               $(6,169)            $(5,574)
#       Other, net                                                                       $(669)              $(889)
#       Net Cash from Financing Activities                                            $(11,799)           $(16,576)
#   Investing
#       Payments for Property, Plant and Equipment                                    $(19,394)           $(14,923)
#       Acquisition of companies, net of cash acquired and divestitures,                 $(578)            $(1,849)
#   and purchases of intangible and other assets
#       Purchases of investments                                                      $(17,671)            $(1,620)
#       Proceeds from Maturities, Prepayments and Calls of Securities                    $6,031              $2,136
#       Sales of investments                                                             $3,262              $1,968
#       Other, net                                                                     $(6,209)              $(913)
#       Net Cash from Investing Activities                                            $(34,559)           $(15,201)
#     Effect of foreign exchange rates on cash and cash equivalents                       $(92)                $122
#     Net Change in Cash                                                               $(1,393)              $2,525
#     Cash and cash equivalents, end of period
#     Cash and cash equivalents, end of period
#
#                   MICROSOFT CORPORATION • Period ending 2025-09-30 • Fiscal Q1 • Source: SEC XBRL

# %%
stmt = xbrl.statements.cashflow_statement()
df = stmt.to_dataframe()

# %%
df["concept"].to_list()
# Out:
# ['us-gaap_StatementOfCashFlowsAbstract',
#  'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents',
#  'us-gaap_NetCashProvidedByUsedInOperatingActivitiesContinuingOperationsAbstract',
#  'us-gaap_NetIncomeLoss',
#  'us-gaap_AdjustmentsToReconcileNetIncomeLossToCashProvidedByUsedInOperatingActivitiesAbstract',
#  'us-gaap_DepreciationDepletionAndAmortization',
#  'us-gaap_ShareBasedCompensation',
#  'us-gaap_OtherNoncashIncomeExpense',
#  'us-gaap_IncreaseDecreaseInOperatingCapitalAbstract',
#  'us-gaap_IncreaseDecreaseInAccountsReceivable',
#  'us-gaap_IncreaseDecreaseInOtherReceivables',
#  'us-gaap_IncreaseDecreaseInInventories',
#  'us-gaap_IncreaseDecreaseInOtherOperatingAssets',
#  'us-gaap_IncreaseDecreaseInAccountsPayable',
#  'us-gaap_IncreaseDecreaseInOtherOperatingLiabilities',
#  'us-gaap_NetCashProvidedByUsedInOperatingActivities',
#  'us-gaap_NetCashProvidedByUsedInInvestingActivitiesContinuingOperationsAbstract',
#  'us-gaap_PaymentsToAcquireAvailableForSaleSecuritiesDebt',
#  'us-gaap_ProceedsFromMaturitiesPrepaymentsAndCallsOfAvailableForSaleSecurities',
#  'us-gaap_ProceedsFromSaleOfAvailableForSaleSecuritiesDebt',
#  'us-gaap_PaymentsToAcquirePropertyPlantAndEquipment',
#  'us-gaap_PaymentsForProceedsFromOtherInvestingActivities',
#  'us-gaap_NetCashProvidedByUsedInInvestingActivities',
#  'us-gaap_NetCashProvidedByUsedInFinancingActivitiesContinuingOperationsAbstract',
#  'us-gaap_PaymentsRelatedToTaxWithholdingForShareBasedCompensation',
#  'us-gaap_PaymentsOfDividends',
#  'us-gaap_PaymentsForRepurchaseOfCommonStock',
#  'us-gaap_ProceedsFromIssuanceOfLongTermDebt',
#  'us-gaap_RepaymentsOfLongTermDebt',
#  'us-gaap_ProceedsFromRepaymentsOfCommercialPaper',
#  'us-gaap_ProceedsFromPaymentsForOtherFinancingActivities',
#  'us-gaap_NetCashProvidedByUsedInFinancingActivities',
#  'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect',
#  'us-gaap_CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalents',
#  'us-gaap_SupplementalCashFlowInformationAbstract',
#  'us-gaap_IncomeTaxesPaidNet']

# %%
import re
import pandas as pd

def tidy_statement_numeric(df):
        
        df = df.copy()
    
        date_cols = [c for c in df.columns if re.match(r"\d{4}-\d{2}-\d{2}", str(c))]
    
        has_value = df[date_cols].apply(pd.to_numeric, errors="coerce").notna().any(axis=1)
        out = df.loc[has_value].copy()
    
        if "preferred_sign" in out.columns:
            for c in date_cols:
                out[c] = pd.to_numeric(out[c], errors="coerce")
            neg = out["preferred_sign"] == -1
            out.loc[neg, date_cols] = -out.loc[neg, date_cols]
    
        keep_cols = ["concept", "label"]
        if "dimension" in out.columns:
            keep_cols.append("dimension")
        if "balance" in out.columns:
            keep_cols.append("balance")
    
        tidy = out[keep_cols + date_cols].sort_values("label").reset_index(drop=True)
        return tidy

# %%
tidy = tidy_statement_numeric(df)

# %%
tidy
# Out:
#                                               concept  \
# 0                      us-gaap_AccountsPayableCurrent
# 1                us-gaap_AccountsReceivableNetCurrent
# 2           us-gaap_EmployeeRelatedLiabilitiesCurrent
# 3   us-gaap_AccumulatedOtherComprehensiveIncomeLos...
# 4       us-gaap_CashAndCashEquivalentsAtCarryingValue
# 5   us-gaap_CashCashEquivalentsAndShortTermInvestm...
# 6   us-gaap_CommonStocksIncludingAdditionalPaidInC...
# 7             us-gaap_DeferredIncomeTaxLiabilitiesNet
# 8                                    us-gaap_Goodwill
# 9              us-gaap_FiniteLivedIntangibleAssetsNet
# 10                               us-gaap_InventoryNet
# 11                     us-gaap_LongTermDebtNoncurrent
# 12                        us-gaap_LongTermInvestments
# 13               us-gaap_AccruedIncomeTaxesNoncurrent
# 14    us-gaap_ContractWithCustomerLiabilityNoncurrent
# 15          us-gaap_OperatingLeaseLiabilityNoncurrent
# 16              us-gaap_OperatingLeaseRightOfUseAsset
# 17                         us-gaap_OtherAssetsCurrent
# 18                    us-gaap_OtherLiabilitiesCurrent
# 19                      us-gaap_OtherAssetsNoncurrent
# 20                 us-gaap_OtherLiabilitiesNoncurrent
# 21               us-gaap_PropertyPlantAndEquipmentNet
# 22         us-gaap_RetainedEarningsAccumulatedDeficit
# 23                        us-gaap_LongTermDebtCurrent
# 24                  us-gaap_AccruedIncomeTaxesCurrent
# 25                       us-gaap_ShortTermInvestments
# 26       us-gaap_ContractWithCustomerLiabilityCurrent
# 27                                     us-gaap_Assets
# 28                              us-gaap_AssetsCurrent
# 29                         us-gaap_LiabilitiesCurrent
# 30                                us-gaap_Liabilities
# 31           us-gaap_LiabilitiesAndStockholdersEquity
# 32                         us-gaap_StockholdersEquity
#
#                                           label  dimension balance  \
# 0                              Accounts Payable      False  credit
# 1                           Accounts Receivable      False   debit
# 2                           Accrued Liabilities      False    None
# 3   Accumulated Other Comprehensive Income/Loss      False  credit
# 4                     Cash and Cash Equivalents      False   debit
# 5                     Cash and Cash Equivalents      False    None
# 6                                  Common Stock      False    None
# 7                         Deferred income taxes      False    None
# 8                                      Goodwill      False   debit
# 9                             Intangible Assets      False    None
# 10                                    Inventory      False   debit
# 11                               Long Term Debt      False  credit
# 12                        Long-Term Investments      False   debit
# 13                       Long-term income taxes      False    None
# 14                   Long-term unearned revenue      False    None
# 15                  Operating lease liabilities      False    None
# 16          Operating lease right-of-use assets      False    None
# 17                         Other Current Assets      False   debit
# 18                    Other Current Liabilities      False  credit
# 19                     Other Non Current Assets      False   debit
# 20                Other Non Current Liabilities      False  credit
# 21                Property, Plant and Equipment      False   debit
# 22                            Retained Earnings      False  credit
# 23                              Short Term Debt      False  credit
# 24                      Short-term income taxes      False  credit
# 25                       Short-term investments      False   debit
# 26                  Short-term unearned revenue      False  credit
# 27                                 Total Assets      False   debit
# 28                         Total Current Assets      False   debit
# 29                    Total Current Liabilities      False  credit
# 30                            Total Liabilities      False  credit
# 31   Total Liabilities and Stockholders' Equity      False  credit
# 32                   Total Stockholders' Equity      False  credit
#
#       2025-09-30    2025-06-30
# 0   3.258000e+10  2.772400e+10
# 1   5.289400e+10  6.990500e+10
# 2   9.201000e+09  1.370900e+10
# 3  -2.761000e+09 -3.347000e+09
# 4   2.884900e+10  3.024200e+10
# 5   1.020120e+11  9.456500e+10
# 6   1.109640e+11  1.090950e+11
# 7   2.852000e+09  2.835000e+09
# 8   1.194970e+11  1.195090e+11
# 9   2.123600e+10  2.260400e+10
# 10  1.130000e+09  9.380000e+08
# 11  3.537600e+10  4.015200e+10
# 12  1.146500e+10  1.540500e+10
# 13  2.656900e+10  2.598600e+10
# 14  2.546000e+09  2.710000e+09
# 15  1.734800e+10  1.743700e+10
# 16  2.479100e+10  2.482300e+10
# 17  3.303000e+10  2.572300e+10
# 18  2.274100e+10  2.502000e+10
# 19  3.943500e+10  4.056500e+10
# 20  5.358800e+10  4.518600e+10
# 21  2.308610e+11  2.049660e+11
# 22  2.548730e+11  2.377310e+11
# 23  7.832000e+09  2.999000e+09
# 24  3.655000e+09  7.211000e+09
# 25  7.316300e+10  6.432300e+10
# 26  5.898700e+10  6.455500e+10
# 27  6.363510e+11  6.190030e+11
# 28  1.890660e+11  1.911310e+11
# 29  1.349960e+11  1.412180e+11
# 30  2.732750e+11  2.755240e+11
# 31  6.363510e+11  6.190030e+11
# 32  3.630760e+11  3.434790e+11
